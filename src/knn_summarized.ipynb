# %% [markdown]
# # Imports

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
import pandas
import numpy
import data_massage
import itertools
import matplotlib.pyplot as plt

# %%
metadata, full_data, induction_only = data_massage.load_data()
summarized_data = data_massage.summarize_data(metadata, induction_only)

knn_data = summarized_data
features = sorted(["R_mean_mean", "Temp_mean", "Humidity_mean", "time_to_gas_max"])

hidden_layers = tuple(map(lambda p: (len(features) ** p), [3,4,5,4,3]))
feature_permutations = list(itertools.chain.from_iterable(map(lambda r: itertools.combinations(features, r), range(1, 1 + len(features)))))

# %%
results = {}

for perm in feature_permutations:
    key = ','.join(perm)
    feature_set = list(perm)

    knn_train_x, knn_test_x, knn_train_y, knn_test_y = train_test_split(
          knn_data[feature_set]
        , knn_data["class"]
        , test_size=0.2
        , stratify=knn_data["class"]
        , random_state=7
    )
    
    knn = KNeighborsClassifier(algorithm="auto", n_neighbors=7, weights="uniform")
    knn.fit(knn_train_x, knn_train_y)
    knn_y_pred = knn.predict(knn_test_x)
    
    report = classification_report(knn_test_y, knn_y_pred, zero_division=False)
    
    results[key] = {"prediction": knn_y_pred, "report": report}
    
    print(key)
    print(report)
    print("\n\n\n")
# Out:
# Humidity_mean
#               precision    recall  f1-score   support
#
#   background       0.30      0.50      0.37         6
#       banana       0.33      0.29      0.31         7
#         wine       0.25      0.14      0.18         7
#
#     accuracy                           0.30        20
#    macro avg       0.29      0.31      0.29        20
# weighted avg       0.29      0.30      0.28        20
#
#
#
#
#
# R_mean_mean
#               precision    recall  f1-score   support
#
#   background       0.43      0.50      0.46         6
#       banana       0.33      0.29      0.31         7
#         wine       0.71      0.71      0.71         7
#
#     accuracy                           0.50        20
#    macro avg       0.49      0.50      0.49        20
# weighted avg       0.50      0.50      0.50        20
#
#
#
#
#
# Temp_mean
#               precision    recall  f1-score   support
#
#   background       0.20      0.17      0.18         6
#       banana       0.40      0.57      0.47         7
#         wine       0.20      0.14      0.17         7
#
#     accuracy                           0.30        20
#    macro avg       0.27      0.29      0.27        20
# weighted avg       0.27      0.30      0.28        20
#
#
#
#
#
# time_to_gas_max
#               precision    recall  f1-score   support
#
#   background       0.14      0.17      0.15         6
#       banana       0.33      0.29      0.31         7
#         wine       0.43      0.43      0.43         7
#
#     accuracy                           0.30        20
#    macro avg       0.30      0.29      0.30        20
# weighted avg       0.31      0.30      0.30        20
#
#
#
#
#
# Humidity_mean,R_mean_mean
#               precision    recall  f1-score   support
#
#   background       0.40      0.67      0.50         6
#       banana       0.25      0.14      0.18         7
#         wine       0.33      0.29      0.31         7
#
#     accuracy                           0.35        20
#    macro avg       0.33      0.37      0.33        20
# weighted avg       0.32      0.35      0.32        20
#
#
#
#
#
# Humidity_mean,Temp_mean
#               precision    recall  f1-score   support
#
#   background       0.38      0.50      0.43         6
#       banana       0.38      0.43      0.40         7
#         wine       0.25      0.14      0.18         7
#
#     accuracy                           0.35        20
#    macro avg       0.33      0.36      0.34        20
# weighted avg       0.33      0.35      0.33        20
#
#
#
#
#
# Humidity_mean,time_to_gas_max
#               precision    recall  f1-score   support
#
#   background       0.14      0.17      0.15         6
#       banana       0.43      0.43      0.43         7
#         wine       0.50      0.43      0.46         7
#
#     accuracy                           0.35        20
#    macro avg       0.36      0.34      0.35        20
# weighted avg       0.37      0.35      0.36        20
#
#
#
#
#
# R_mean_mean,Temp_mean
#               precision    recall  f1-score   support
#
#   background       0.50      0.33      0.40         6
#       banana       0.40      0.29      0.33         7
#         wine       0.45      0.71      0.56         7
#
#     accuracy                           0.45        20
#    macro avg       0.45      0.44      0.43        20
# weighted avg       0.45      0.45      0.43        20
#
#
#
#
#
# R_mean_mean,time_to_gas_max
#               precision    recall  f1-score   support
#
#   background       0.14      0.17      0.15         6
#       banana       0.40      0.29      0.33         7
#         wine       0.50      0.57      0.53         7
#
#     accuracy                           0.35        20
#    macro avg       0.35      0.34      0.34        20
# weighted avg       0.36      0.35      0.35        20
#
#
#
#
#
# Temp_mean,time_to_gas_max
#               precision    recall  f1-score   support
#
#   background       0.14      0.17      0.15         6
#       banana       0.40      0.29      0.33         7
#         wine       0.50      0.57      0.53         7
#
#     accuracy                           0.35        20
#    macro avg       0.35      0.34      0.34        20
# weighted avg       0.36      0.35      0.35        20
#
#
#
#
#
# Humidity_mean,R_mean_mean,Temp_mean
#               precision    recall  f1-score   support
#
#   background       0.40      0.67      0.50         6
#       banana       0.50      0.57      0.53         7
#         wine       1.00      0.29      0.44         7
#
#     accuracy                           0.50        20
#    macro avg       0.63      0.51      0.49        20
# weighted avg       0.65      0.50      0.49        20
#
#
#
#
#
# Humidity_mean,R_mean_mean,time_to_gas_max
#               precision    recall  f1-score   support
#
#   background       0.14      0.17      0.15         6
#       banana       0.43      0.43      0.43         7
#         wine       0.50      0.43      0.46         7
#
#     accuracy                           0.35        20
#    macro avg       0.36      0.34      0.35        20
# weighted avg       0.37      0.35      0.36        20
#
#
#
#
#
# Humidity_mean,Temp_mean,time_to_gas_max
#               precision    recall  f1-score   support
#
#   background       0.14      0.17      0.15         6
#       banana       0.43      0.43      0.43         7
#         wine       0.50      0.43      0.46         7
#
#     accuracy                           0.35        20
#    macro avg       0.36      0.34      0.35        20
# weighted avg       0.37      0.35      0.36        20
#
#
#
#
#
# R_mean_mean,Temp_mean,time_to_gas_max
#               precision    recall  f1-score   support
#
#   background       0.14      0.17      0.15         6
#       banana       0.40      0.29      0.33         7
#         wine       0.50      0.57      0.53         7
#
#     accuracy                           0.35        20
#    macro avg       0.35      0.34      0.34        20
# weighted avg       0.36      0.35      0.35        20
#
#
#
#
#
# Humidity_mean,R_mean_mean,Temp_mean,time_to_gas_max
#               precision    recall  f1-score   support
#
#   background       0.14      0.17      0.15         6
#       banana       0.43      0.43      0.43         7
#         wine       0.50      0.43      0.46         7
#
#     accuracy                           0.35        20
#    macro avg       0.36      0.34      0.35        20
# weighted avg       0.37      0.35      0.36        20
